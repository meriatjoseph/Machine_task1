# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics

# %%
df1=pd.read_csv('train_FD001.txt', sep=' ',header=None)
df1
# Out:
#         0    1       2       3      4       5       6        7        8   \
# 0        1    1 -0.0007 -0.0004  100.0  518.67  641.82  1589.70  1400.60
# 1        1    2  0.0019 -0.0003  100.0  518.67  642.15  1591.82  1403.14
# 2        1    3 -0.0043  0.0003  100.0  518.67  642.35  1587.99  1404.20
# 3        1    4  0.0007  0.0000  100.0  518.67  642.35  1582.79  1401.87
# 4        1    5 -0.0019 -0.0002  100.0  518.67  642.37  1582.85  1406.22
# ...    ...  ...     ...     ...    ...     ...     ...      ...      ...
# 20626  100  196 -0.0004 -0.0003  100.0  518.67  643.49  1597.98  1428.63
# 20627  100  197 -0.0016 -0.0005  100.0  518.67  643.54  1604.50  1433.58
# 20628  100  198  0.0004  0.0000  100.0  518.67  643.42  1602.46  1428.18
# 20629  100  199 -0.0011  0.0003  100.0  518.67  643.23  1605.26  1426.53
# 20630  100  200 -0.0032 -0.0005  100.0  518.67  643.85  1600.38  1432.14
#
#           9   ...       18      19    20   21    22     23     24       25  \
# 0      14.62  ...  8138.62  8.4195  0.03  392  2388  100.0  39.06  23.4190
# 1      14.62  ...  8131.49  8.4318  0.03  392  2388  100.0  39.00  23.4236
# 2      14.62  ...  8133.23  8.4178  0.03  390  2388  100.0  38.95  23.3442
# 3      14.62  ...  8133.83  8.3682  0.03  392  2388  100.0  38.88  23.3739
# 4      14.62  ...  8133.80  8.4294  0.03  393  2388  100.0  38.90  23.4044
# ...      ...  ...      ...     ...   ...  ...   ...    ...    ...      ...
# 20626  14.62  ...  8137.60  8.4956  0.03  397  2388  100.0  38.49  22.9735
# 20627  14.62  ...  8136.50  8.5139  0.03  395  2388  100.0  38.30  23.1594
# 20628  14.62  ...  8141.05  8.5646  0.03  398  2388  100.0  38.44  22.9333
# 20629  14.62  ...  8139.29  8.5389  0.03  395  2388  100.0  38.29  23.0640
# 20630  14.62  ...  8137.33  8.5036  0.03  396  2388  100.0  38.37  23.0522
#
#        26  27
# 0     NaN NaN
# 1     NaN NaN
# 2     NaN NaN
# 3     NaN NaN
# 4     NaN NaN
# ...    ..  ..
# 20626 NaN NaN
# 20627 NaN NaN
# 20628 NaN NaN
# 20629 NaN NaN
# 20630 NaN NaN
#
# [20631 rows x 28 columns]

# %%
df1 = df1.drop([26, 27], axis='columns', errors='ignore')

df1
# Out:
#         0    1       2       3      4       5       6        7        8   \
# 0        1    1 -0.0007 -0.0004  100.0  518.67  641.82  1589.70  1400.60
# 1        1    2  0.0019 -0.0003  100.0  518.67  642.15  1591.82  1403.14
# 2        1    3 -0.0043  0.0003  100.0  518.67  642.35  1587.99  1404.20
# 3        1    4  0.0007  0.0000  100.0  518.67  642.35  1582.79  1401.87
# 4        1    5 -0.0019 -0.0002  100.0  518.67  642.37  1582.85  1406.22
# ...    ...  ...     ...     ...    ...     ...     ...      ...      ...
# 20626  100  196 -0.0004 -0.0003  100.0  518.67  643.49  1597.98  1428.63
# 20627  100  197 -0.0016 -0.0005  100.0  518.67  643.54  1604.50  1433.58
# 20628  100  198  0.0004  0.0000  100.0  518.67  643.42  1602.46  1428.18
# 20629  100  199 -0.0011  0.0003  100.0  518.67  643.23  1605.26  1426.53
# 20630  100  200 -0.0032 -0.0005  100.0  518.67  643.85  1600.38  1432.14
#
#           9   ...      16       17       18      19    20   21    22     23  \
# 0      14.62  ...  521.66  2388.02  8138.62  8.4195  0.03  392  2388  100.0
# 1      14.62  ...  522.28  2388.07  8131.49  8.4318  0.03  392  2388  100.0
# 2      14.62  ...  522.42  2388.03  8133.23  8.4178  0.03  390  2388  100.0
# 3      14.62  ...  522.86  2388.08  8133.83  8.3682  0.03  392  2388  100.0
# 4      14.62  ...  522.19  2388.04  8133.80  8.4294  0.03  393  2388  100.0
# ...      ...  ...     ...      ...      ...     ...   ...  ...   ...    ...
# 20626  14.62  ...  519.49  2388.26  8137.60  8.4956  0.03  397  2388  100.0
# 20627  14.62  ...  519.68  2388.22  8136.50  8.5139  0.03  395  2388  100.0
# 20628  14.62  ...  520.01  2388.24  8141.05  8.5646  0.03  398  2388  100.0
# 20629  14.62  ...  519.67  2388.23  8139.29  8.5389  0.03  395  2388  100.0
# 20630  14.62  ...  519.30  2388.26  8137.33  8.5036  0.03  396  2388  100.0
#
#           24       25
# 0      39.06  23.4190
# 1      39.00  23.4236
# 2      38.95  23.3442
# 3      38.88  23.3739
# 4      38.90  23.4044
# ...      ...      ...
# 20626  38.49  22.9735
# 20627  38.30  23.1594
# 20628  38.44  22.9333
# 20629  38.29  23.0640
# 20630  38.37  23.0522
#
# [20631 rows x 26 columns]

# %%
df1.columns=["ID","Cycle","OpSet1","OpSet2","OpSet3","SensorMeasure_1","SensorMeasure_2","SensorMeasure_3","SensorMeasure_4","SensorMeasure_5","SensorMeasure_6","SensorMeasure_7","SensorMeasure_8","SensorMeasure_9","SensorMeasure_10","SensorMeasure_11","SensorMeasure_12","SensorMeasure_13","SensorMeasure_14","SensorMeasure_15","SensorMeasure_16","SensorMeasure_17","SensorMeasure_18","SensorMeasure_19","SensorMeasure_20","SensorMeasure_21"]

# %%
df1['RUL']=RUL

# %%
df1
# Out:
#         ID  Cycle  OpSet1  OpSet2  OpSet3  SensorMeasure_1  SensorMeasure_2  \
# 0        1      1 -0.0007 -0.0004   100.0           518.67           641.82
# 1        1      2  0.0019 -0.0003   100.0           518.67           642.15
# 2        1      3 -0.0043  0.0003   100.0           518.67           642.35
# 3        1      4  0.0007  0.0000   100.0           518.67           642.35
# 4        1      5 -0.0019 -0.0002   100.0           518.67           642.37
# ...    ...    ...     ...     ...     ...              ...              ...
# 20626  100    196 -0.0004 -0.0003   100.0           518.67           643.49
# 20627  100    197 -0.0016 -0.0005   100.0           518.67           643.54
# 20628  100    198  0.0004  0.0000   100.0           518.67           643.42
# 20629  100    199 -0.0011  0.0003   100.0           518.67           643.23
# 20630  100    200 -0.0032 -0.0005   100.0           518.67           643.85
#
#        SensorMeasure_3  SensorMeasure_4  SensorMeasure_5  ...  \
# 0              1589.70          1400.60            14.62  ...
# 1              1591.82          1403.14            14.62  ...
# 2              1587.99          1404.20            14.62  ...
# 3              1582.79          1401.87            14.62  ...
# 4              1582.85          1406.22            14.62  ...
# ...                ...              ...              ...  ...
# 20626          1597.98          1428.63            14.62  ...
# 20627          1604.50          1433.58            14.62  ...
# 20628          1602.46          1428.18            14.62  ...
# 20629          1605.26          1426.53            14.62  ...
# 20630          1600.38          1432.14            14.62  ...
#
#        SensorMeasure_13  SensorMeasure_14  SensorMeasure_15  SensorMeasure_16  \
# 0               2388.02           8138.62            8.4195              0.03
# 1               2388.07           8131.49            8.4318              0.03
# 2               2388.03           8133.23            8.4178              0.03
# 3               2388.08           8133.83            8.3682              0.03
# 4               2388.04           8133.80            8.4294              0.03
# ...                 ...               ...               ...               ...
# 20626           2388.26           8137.60            8.4956              0.03
# 20627           2388.22           8136.50            8.5139              0.03
# 20628           2388.24           8141.05            8.5646              0.03
# 20629           2388.23           8139.29            8.5389              0.03
# 20630           2388.26           8137.33            8.5036              0.03
#
#        SensorMeasure_17  SensorMeasure_18  SensorMeasure_19  SensorMeasure_20  \
# 0                   392              2388             100.0             39.06
# 1                   392              2388             100.0             39.00
# 2                   390              2388             100.0             38.95
# 3                   392              2388             100.0             38.88
# 4                   393              2388             100.0             38.90
# ...                 ...               ...               ...               ...
# 20626               397              2388             100.0             38.49
# 20627               395              2388             100.0             38.30
# 20628               398              2388             100.0             38.44
# 20629               395              2388             100.0             38.29
# 20630               396              2388             100.0             38.37
#
#        SensorMeasure_21  RUL
# 0               23.4190  192
# 1               23.4236  192
# 2               23.3442  192
# 3               23.3739  192
# 4               23.4044  192
# ...                 ...  ...
# 20626           22.9735  200
# 20627           23.1594  200
# 20628           22.9333  200
# 20629           23.0640  200
# 20630           23.0522  200
#
# [20631 rows x 27 columns]

# %%
#Drop ID 

df1=df1.drop(columns=['ID'])

# %%
df1
# Out:
#        Cycle  OpSet1  OpSet2  OpSet3  SensorMeasure_1  SensorMeasure_2  \
# 0          1 -0.0007 -0.0004   100.0           518.67           641.82
# 1          2  0.0019 -0.0003   100.0           518.67           642.15
# 2          3 -0.0043  0.0003   100.0           518.67           642.35
# 3          4  0.0007  0.0000   100.0           518.67           642.35
# 4          5 -0.0019 -0.0002   100.0           518.67           642.37
# ...      ...     ...     ...     ...              ...              ...
# 20626    196 -0.0004 -0.0003   100.0           518.67           643.49
# 20627    197 -0.0016 -0.0005   100.0           518.67           643.54
# 20628    198  0.0004  0.0000   100.0           518.67           643.42
# 20629    199 -0.0011  0.0003   100.0           518.67           643.23
# 20630    200 -0.0032 -0.0005   100.0           518.67           643.85
#
#        SensorMeasure_3  SensorMeasure_4  SensorMeasure_5  SensorMeasure_6  \
# 0              1589.70          1400.60            14.62            21.61
# 1              1591.82          1403.14            14.62            21.61
# 2              1587.99          1404.20            14.62            21.61
# 3              1582.79          1401.87            14.62            21.61
# 4              1582.85          1406.22            14.62            21.61
# ...                ...              ...              ...              ...
# 20626          1597.98          1428.63            14.62            21.61
# 20627          1604.50          1433.58            14.62            21.61
# 20628          1602.46          1428.18            14.62            21.61
# 20629          1605.26          1426.53            14.62            21.61
# 20630          1600.38          1432.14            14.62            21.61
#
#        ...  SensorMeasure_13  SensorMeasure_14  SensorMeasure_15  \
# 0      ...           2388.02           8138.62            8.4195
# 1      ...           2388.07           8131.49            8.4318
# 2      ...           2388.03           8133.23            8.4178
# 3      ...           2388.08           8133.83            8.3682
# 4      ...           2388.04           8133.80            8.4294
# ...    ...               ...               ...               ...
# 20626  ...           2388.26           8137.60            8.4956
# 20627  ...           2388.22           8136.50            8.5139
# 20628  ...           2388.24           8141.05            8.5646
# 20629  ...           2388.23           8139.29            8.5389
# 20630  ...           2388.26           8137.33            8.5036
#
#        SensorMeasure_16  SensorMeasure_17  SensorMeasure_18  SensorMeasure_19  \
# 0                  0.03               392              2388             100.0
# 1                  0.03               392              2388             100.0
# 2                  0.03               390              2388             100.0
# 3                  0.03               392              2388             100.0
# 4                  0.03               393              2388             100.0
# ...                 ...               ...               ...               ...
# 20626              0.03               397              2388             100.0
# 20627              0.03               395              2388             100.0
# 20628              0.03               398              2388             100.0
# 20629              0.03               395              2388             100.0
# 20630              0.03               396              2388             100.0
#
#        SensorMeasure_20  SensorMeasure_21  RUL
# 0                 39.06           23.4190  192
# 1                 39.00           23.4236  192
# 2                 38.95           23.3442  192
# 3                 38.88           23.3739  192
# 4                 38.90           23.4044  192
# ...                 ...               ...  ...
# 20626             38.49           22.9735  200
# 20627             38.30           23.1594  200
# 20628             38.44           22.9333  200
# 20629             38.29           23.0640  200
# 20630             38.37           23.0522  200
#
# [20631 rows x 26 columns]

# %%
df1.describe()
# Out:
#               Cycle        OpSet1        OpSet2   OpSet3  SensorMeasure_1  \
# count  20631.000000  20631.000000  20631.000000  20631.0     2.063100e+04
# mean     108.807862     -0.000009      0.000002    100.0     5.186700e+02
# std       68.880990      0.002187      0.000293      0.0     6.537152e-11
# min        1.000000     -0.008700     -0.000600    100.0     5.186700e+02
# 25%       52.000000     -0.001500     -0.000200    100.0     5.186700e+02
# 50%      104.000000      0.000000      0.000000    100.0     5.186700e+02
# 75%      156.000000      0.001500      0.000300    100.0     5.186700e+02
# max      362.000000      0.008700      0.000600    100.0     5.186700e+02
#
#        SensorMeasure_2  SensorMeasure_3  SensorMeasure_4  SensorMeasure_5  \
# count     20631.000000     20631.000000     20631.000000     2.063100e+04
# mean        642.680934      1590.523119      1408.933782     1.462000e+01
# std           0.500053         6.131150         9.000605     3.394700e-12
# min         641.210000      1571.040000      1382.250000     1.462000e+01
# 25%         642.325000      1586.260000      1402.360000     1.462000e+01
# 50%         642.640000      1590.100000      1408.040000     1.462000e+01
# 75%         643.000000      1594.380000      1414.555000     1.462000e+01
# max         644.530000      1616.910000      1441.490000     1.462000e+01
#
#        SensorMeasure_6  ...  SensorMeasure_13  SensorMeasure_14  \
# count     20631.000000  ...      20631.000000      20631.000000
# mean         21.609803  ...       2388.096152       8143.752722
# std           0.001389  ...          0.071919         19.076176
# min          21.600000  ...       2387.880000       8099.940000
# 25%          21.610000  ...       2388.040000       8133.245000
# 50%          21.610000  ...       2388.090000       8140.540000
# 75%          21.610000  ...       2388.140000       8148.310000
# max          21.610000  ...       2388.560000       8293.720000
#
#        SensorMeasure_15  SensorMeasure_16  SensorMeasure_17  SensorMeasure_18  \
# count      20631.000000      2.063100e+04      20631.000000           20631.0
# mean           8.442146      3.000000e-02        393.210654            2388.0
# std            0.037505      1.556432e-14          1.548763               0.0
# min            8.324900      3.000000e-02        388.000000            2388.0
# 25%            8.414900      3.000000e-02        392.000000            2388.0
# 50%            8.438900      3.000000e-02        393.000000            2388.0
# 75%            8.465600      3.000000e-02        394.000000            2388.0
# max            8.584800      3.000000e-02        400.000000            2388.0
#
#        SensorMeasure_19  SensorMeasure_20  SensorMeasure_21           RUL
# count           20631.0      20631.000000      20631.000000  20631.000000
# mean              100.0         38.816271         23.289705    216.615724
# std                 0.0          0.180746          0.108251     50.028600
# min               100.0         38.140000         22.894200    128.000000
# 25%               100.0         38.700000         23.221800    185.000000
# 50%               100.0         38.830000         23.297900    207.000000
# 75%               100.0         38.950000         23.366800    240.000000
# max               100.0         39.430000         23.618400    362.000000
#
# [8 rows x 26 columns]

# %%
df1.nunique(axis=0)
# Out:
# Cycle                362
# OpSet1               158
# OpSet2                13
# OpSet3                 1
# SensorMeasure_1        1
# SensorMeasure_2      310
# SensorMeasure_3     3012
# SensorMeasure_4     4051
# SensorMeasure_5        1
# SensorMeasure_6        2
# SensorMeasure_7      513
# SensorMeasure_8       53
# SensorMeasure_9     6403
# SensorMeasure_10       1
# SensorMeasure_11     159
# SensorMeasure_12     427
# SensorMeasure_13      56
# SensorMeasure_14    6078
# SensorMeasure_15    1918
# SensorMeasure_16       1
# SensorMeasure_17      13
# SensorMeasure_18       1
# SensorMeasure_19       1
# SensorMeasure_20     120
# SensorMeasure_21    4745
# RUL                   66
# dtype: int64

# %%
#Box plot

plt.figure(figsize=(15,21))
for i in np.arange(1,25):
    temp=df1.iloc[:,i]
    plt.subplot(5,6,i)
    plt.boxplot(temp) #Make a box and whisker plot
    plt.title(df1.columns[i])
plt.show()

# %%
# Compute the correlation matrix
corrmat = df1.corr()

# Get the top correlated features
top_corr_features = corrmat.index

# Set up the plot size
plt.figure(figsize=(58, 58))

# Set the font scale and style
sns.set(font_scale=4, font="Times New Roman")

# Plot the heatmap
g = sns.heatmap(df[top_corr_features].corr(), 
                cmap='RdYlGn', 
                linewidths=0.1, 
                annot=True, 
                annot_kws={'size': 35})

# Adjust the font size of tick labels
g.set_xticklabels(g.get_xmajorticklabels(), fontsize=35)
g.set_yticklabels(g.get_ymajorticklabels(), fontsize=35)

# Save the figure (optional)
# plt.savefig('Corrplot.png', bbox_inches='tight')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 14
#      11 sns.set(font_scale=4, font="Times New Roman")
#      13 # Plot the heatmap
# ---> 14 g = sns.heatmap(df[top_corr_features].corr(),
#      15                 cmap='RdYlGn',
#      16                 linewidths=0.1,
#      17                 annot=True,
#      18                 annot_kws={'size': 35})
#      20 # Adjust the font size of tick labels
#      21 g.set_xticklabels(g.get_xmajorticklabels(), fontsize=35)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['RUL'] not in index"
